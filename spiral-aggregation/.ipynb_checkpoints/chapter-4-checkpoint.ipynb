# %% [markdown]
# # Degrading the data
#
# What happens when we lower the retirement limit of a galaxy? Can we still recover meaningful spiral arms?
#
# This is the question we explore in this chapter: we take our 47 classifications and obtain samples of ten

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import numpy as np
import groupPolylines
import spiralExtraction
import json

# %%
with open('classification-dump.json') as f: classifications = json.load(f)
with open('subject-dump.json') as f: subjects = json.load(f)
# print(json.dumps(list(cls[0]['links']['subjects']), indent=1))
index, _ = (next(iter(filter(
    lambda s: s[1] == '6ee8db8f-2a1e-4d10-bcb9-1e5ec84f8f10',
    ((i, list(s['locations'][0].items())[0][1].split('/')[-1].split('.')[0]) for i, s in enumerate(subjects))
))))

subjectId = subjects[index]['id']

classificationsOfSubject = list(filter(lambda c: c['links']['subjects'][0] == subjectId, classifications))
annotations = [c['annotations'] for c in classificationsOfSubject]
annotationsWithSpiral = [c[3]['value'][0]['value'] for c in annotations if len(c[3]['value'][0]['value'])]
spirals = [[a['points'] for a in c] for c in annotationsWithSpiral]
spiralsWithLengthCut = [
    [[[p['x'], p['y']] for p in a] for a in c]
    for c in spirals if all([len(a) > 5 for a in c])
]
drawnArms = np.array([np.array(arm) for classification in spiralsWithLengthCut for arm in classification])

# %%
np.random.seed(0)
classificationGroups = [np.random.choice(np.arange(len(annotations)), size=30, replace=False) for i in range(5)]
classificationGroups
# Out:
# [array([28, 33, 30,  4, 18, 11, 42, 31, 22, 10, 27, 32, 29, 43,  2, 45, 26,
#         15, 25, 16, 40, 20, 41,  8, 13,  5, 17, 34, 14, 37]),
#  array([21, 30, 33, 37,  2, 16, 29, 20,  8, 38, 22, 19, 13, 44, 26, 41, 24,
#         46, 12, 27, 42, 39, 18, 14, 43, 45,  6,  3, 25,  9]),
#  array([33, 12,  7, 15, 40, 27, 39, 20, 25,  8,  6, 16,  4,  1, 43, 44, 19,
#         17, 32, 14, 28, 22, 37, 24,  2, 23, 26, 11, 18, 10]),
#  array([17, 15,  7, 32, 10, 46, 36, 25, 33, 39,  1, 35,  5,  6,  9, 28, 18,
#         27, 16, 22, 21, 23, 11, 38, 29,  4,  0, 14, 12, 41]),
#  array([21, 14, 36, 30, 26,  4, 35, 16, 45,  9, 25, 17,  2, 19, 27, 46, 23,
#         20, 28,  8, 33,  0, 38,  5, 22, 37,  6, 12, 10, 32])]

# %%
foo = []
for groupIndex, indices in enumerate(classificationGroups[:]):
    print(groupIndex)
    filteredAnnotations = [annotations[i] for i in indices]
    annotationsWithSpiral = [c[3]['value'][0]['value'] for c in filteredAnnotations if len(c[3]['value'][0]['value'])]
    spirals = [[a['points'] for a in c] for c in annotationsWithSpiral]
    spiralsWithLengthCut = [
        [[[p['x'], p['y']] for p in a] for a in c]
        for c in spirals if all([len(a) > 5 for a in c])
    ]
    drawnArms = np.array([np.array(arm) for classification in spiralsWithLengthCut for arm in classification])
    t = np.linspace(0, 1, 1000)
    functions = spiralExtraction.fit(drawnArms, verbose=False)
    foo.append(functions)
    for i, (Sx, Sy) in enumerate(functions):
        plt.plot((Sx(t) + 0.5) * 512, (Sy(t) + 0.5) * 512, linewidth=3, alpha=0.5, label="{}.{}".format(groupIndex, i))
        
plt.legend()
# Out:
# 0
# SpEx - Calculating distance matrix (this can be slow)
# SpEx - Clustering arms
# SpEx - Working on arm label 0
# SpEx - 	[1 / 4] Cleaning points (1588 total)
# SpEx - 	[2 / 4] Identifiying most representitive arm
# SpEx - 	[3 / 4] Sorting points
# SpEx - 	[4 / 4] Fitting Spline
# SpEx - Working on arm label 1
# SpEx - 	[1 / 4] Cleaning points (1790 total)
# SpEx - 	[2 / 4] Identifiying most representitive arm
# SpEx - 	[3 / 4] Sorting points
# SpEx - 	[4 / 4] Fitting Spline
# SpEx - done!
# 1
# SpEx - Calculating distance matrix (this can be slow)
# SpEx - Clustering arms
# SpEx - Working on arm label 0
# SpEx - 	[1 / 4] Cleaning points (1650 total)
# SpEx - 	[2 / 4] Identifiying most representitive arm
# SpEx - 	[3 / 4] Sorting points
# SpEx - 	[4 / 4] Fitting Spline
# SpEx - Working on arm label 1
# SpEx - 	[1 / 4] Cleaning points (1157 total)
# SpEx - 	[2 / 4] Identifiying most representitive arm
# SpEx - 	[3 / 4] Sorting points
# SpEx - 	[4 / 4] Fitting Spline
# SpEx - Working on arm label 2
# SpEx - 	[1 / 4] Cleaning points (130 total)
# SpEx - 	[2 / 4] Identifiying most representitive arm
# SpEx - 	[3 / 4] Sorting points
# SpEx - 	[4 / 4] Fitting Spline
# SpEx - done!
# 2
# SpEx - Calculating distance matrix (this can be slow)
# SpEx - Clustering arms
# SpEx - Working on arm label 0
# SpEx - 	[1 / 4] Cleaning points (1846 total)
# SpEx - 	[2 / 4] Identifiying most representitive arm
# SpEx - 	[3 / 4] Sorting points
# SpEx - 	[4 / 4] Fitting Spline
# SpEx - Working on arm label 1
# SpEx - 	[1 / 4] Cleaning points (2397 total)
# SpEx - 	[2 / 4] Identifiying most representitive arm
# SpEx - 	[3 / 4] Sorting points
# SpEx - 	[4 / 4] Fitting Spline
# SpEx - done!
# 3
# SpEx - Calculating distance matrix (this can be slow)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-a0d4c6251cfb> in <module>()
#      11     drawnArms = np.array([np.array(arm) for classification in spiralsWithLengthCut for arm in classification])
#      12     t = np.linspace(0, 1, 1000)
# ---> 13     functions = spiralExtraction.fit(drawnArms, verbose=1)
#      14     foo.append(functions)
#      15     for i, (Sx, Sy) in enumerate(functions):
#
# /Users/tlingard/PhD/galaxy-builder/data-aggregation/spiral-aggregation/spiralExtraction.py in fit(drawnArms, imageSize, verbose)
#     177     t = np.linspace(0, 1, points.shape[0])
#     178     Sx = UnivariateSpline(t, _points[:, 0], s=0.25, k=5)
# --> 179     Sy = UnivariateSpline(t, _points[:, 1], s=0.25, k=5)
#     180     return (Sx, Sy)
#     181
#
# /Users/tlingard/PhD/galaxy-builder/data-aggregation/spiral-aggregation/spiralExtraction.py in calculateDistanceMatrix(cls)
#      77     return (
#      78         minimum_distance(a, b) +
# ---> 79         minimum_distance(b, a)
#      80     )
#      81
#
# /Users/tlingard/PhD/galaxy-builder/data-aggregation/spiral-aggregation/spiralExtraction.py in arcDistanceFast(a, b)
#      69     m[:, :, 2, :] = np.tile(
#      70         np.roll(b, -1, axis=0), [a.shape[0], 1, 1]
# ---> 71     )[:, :-1, :]
#      72     t = vCalcT(np.array(m))
#      73     return np.sum(vGetDiff(t, m)) / a.shape[0]
#
# /Users/tlingard/PhD/galaxy-builder/data-aggregation/spiral-aggregation/spiralExtraction.py in minimum_distance(a, b)
#      63     m = np.zeros((a.shape[0], b.shape[0] - 1, 3, 2))
#      64     m[:, :, 0, :] = np.transpose(
# ---> 65         np.tile(a, [m.shape[1] + 1, 1, 1]),
#      66         axes=[1, 0, 2]
#      67     )[:, :-1, :]
#
# /Users/tlingard/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py in __call__(self, *args, **kwargs)
#    2753             vargs.extend([kwargs[_n] for _n in names])
#    2754
# -> 2755         return self._vectorize_call(func=func, args=vargs)
#    2756
#    2757     def _get_ufunc_and_otypes(self, func, args):
#
# /Users/tlingard/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py in _vectorize_call(self, func, args)
#    2819         """Vectorized call to `func` over positional `args`."""
#    2820         if self.signature is not None:
# -> 2821             res = self._vectorize_call_with_signature(func, args)
#    2822         elif not args:
#    2823             res = func()
#
# /Users/tlingard/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py in _vectorize_call_with_signature(self, func, args)
#    2860
#    2861         for index in np.ndindex(*broadcast_shape):
# -> 2862             results = func(*(arg[index] for arg in args))
#    2863
#    2864             n_results = len(results) if isinstance(results, tuple) else 1
#
# /Users/tlingard/PhD/galaxy-builder/data-aggregation/spiral-aggregation/spiralExtraction.py in getDiff(t, a)
#      44     return out
#      45
# ---> 46
#      47 def getDiff(t, a):
#      48     projection = a[:, 1, :] + np.repeat(
#
# KeyboardInterrupt:

# %%
from sklearn.cluster import DBSCAN
indices = classificationGroups[1]
filteredAnnotations = [annotations[i] for i in indices]
annotationsWithSpiral = [c[3]['value'][0]['value'] for c in filteredAnnotations if len(c[3]['value'][0]['value'])]
spirals = [[a['points'] for a in c] for c in annotationsWithSpiral]
spiralsWithLengthCut = [
    [[[p['x'], p['y']] for p in a] for a in c]
    for c in spirals if all([len(a) > 5 for a in c])
]
drawnArms = np.array([np.array(arm) for classification in spiralsWithLengthCut for arm in classification])

# %%
distances = spiralExtraction.calculateDistanceMatrix(drawnArms)

# %%
db = DBSCAN(
    eps=20,
    min_samples=3,
    metric='precomputed',
    n_jobs=-1,
    algorithm='brute'
).fit(distances)

# %%
label = 1
pointCloud = np.array([
    point for arm in drawnArms[db.labels_ == label]
    for point in arm
])
plt.plot(pointCloud[:, 0], pointCloud[:, 1], '.')
