# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_pickle('model-comparison-results.pkl')

# %%
df.head()
# Out:
#              dr8objid  log_spiral  log_spiral_std          mass  \
# 0  587724649793650785   -0.475696        0.389942  2.380138e+09
# 1  587724649793650785   -0.676568        0.090816  8.929483e+09
# 2  587725550661992687   -0.791745        0.067398  8.929483e+09
# 3  587724649793650785   -0.838294        0.083594  1.198687e+10
# 4  587725550661992687   -0.726456        0.061980  1.198687e+10
#
#    poly_spiral_1  poly_spiral_1_std  poly_spiral_2  poly_spiral_2_std  \
# 0      -0.326971           0.448734      -0.614449           0.260602
# 1      -0.699216           0.060425      -0.785103           0.039277
# 2      -0.795337           0.072739      -0.780158           0.067474
# 3      -0.868722           0.057065      -0.846236           0.071638
# 4      -0.739097           0.078176      -0.715023           0.077587
#
#    poly_spiral_3  poly_spiral_3_std  poly_spiral_4  poly_spiral_4_std
# 0      -0.609979           0.244360      -0.650470           0.242904
# ...

# %%
df.describe()
# Out:
#        log_spiral  log_spiral_std          mass  poly_spiral_1  \
# count  176.000000      176.000000  1.760000e+02   1.760000e+02
# mean     5.669835        9.787237  9.035688e+09   2.561345e+04
# std     60.648046       98.939792  1.190629e+10   3.243645e+05
# min     -0.949235        0.020973  5.377208e+07  -9.289539e-01
# 25%     -0.681055        0.176719  2.817549e+09  -6.794251e-01
# 50%     -0.370016        0.440682  4.946294e+09  -2.171045e-01
# 75%      0.936276        1.513712  9.733906e+09   1.741974e+00
# max    803.604510     1311.814287  9.870334e+10   4.301668e+06
#
#        poly_spiral_1_std  poly_spiral_2  poly_spiral_2_std  poly_spiral_3  \
# count       1.760000e+02   1.760000e+02       1.760000e+02   1.760000e+02
# mean        3.838810e+04   8.931343e+04       1.490076e+05   1.585840e+05
# std         4.954599e+05   1.177317e+06       1.970239e+06   2.098479e+06
# min         1.494820e-02  -9.372034e-01       1.530880e-02  -9.423455e-01
# ...
